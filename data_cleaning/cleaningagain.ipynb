# %%
import pandas as pd
import numpy as np

# %%
# From Data file we will import the finall_data.xlsx

df = pd.read_excel(r'C:\Users\Dell\OneDrive\Desktop\advance web scraping\Nakri_data_set\Skill_Gap_Analysis_Tool\Data\Finall_data.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10163 entries, 0 to 10162
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0.1            10163 non-null  int64
#  1   Unnamed: 0              10163 non-null  int64
#  2   Job_role                10163 non-null  object
#  3   Company                 10163 non-null  object
#  4   job_pay                 10163 non-null  object
#  5   location                10163 non-null  object
#  6   Description             10163 non-null  object
#  7   review                  10163 non-null  float64
#  8   Job post length         10163 non-null  int64
#  9   min_year                10163 non-null  int64
#  10  max_year                10163 non-null  int64
#  11  more_branch             10163 non-null  int64
#  12  +3_branches             10163 non-null  int64
#  13  days                    10163 non-null  int64
#  14  skill_1                 10126 non-null  object
#  15  skill_2                 10142 non-null  object
#  16  skill_3                 10117 non-null  object
#  17  skill_4                 10031 non-null  object
#  18  skill_5                 9911 non-null   object
#  19  skill_6                 9793 non-null   object
#  20  skill_7                 9664 non-null   object
#  21  skill_8                 9525 non-null   object
#  22  skill_9                 258 non-null    object
#  23  skill_10                19 non-null     object
#  24  is_remote               10163 non-null  int64
#  25  norm_review             10163 non-null  float64
#  26  norm_branches           10163 non-null  int64
#  27  norm_max_year           10163 non-null  float64
#  28  composite_score         10163 non-null  float64
#  29  Company Size            10163 non-null  object
#  30  Job Category            10163 non-null  object
#  31  Primary Skill Category  10163 non-null  object
# dtypes: float64(4), int64(10), object(18)
# memory usage: 2.5+ MB

# %%
# removed the use less columns  
df.drop(columns=['Unnamed: 0.1'	,'Unnamed: 0'	],inplace=True)
df.head()
df.columns
# Out:
# Index(['Job_role', 'Company', 'job_pay', 'location', 'Description', 'review',
#        'Job post length', 'min_year', 'max_year', 'more_branch', '+3_branches',
#        'days', 'skill_1', 'skill_2', 'skill_3', 'skill_4', 'skill_5',
#        'skill_6', 'skill_7', 'skill_8', 'skill_9', 'skill_10', 'is_remote',
#        'norm_review', 'norm_branches', 'norm_max_year', 'composite_score',
#        'Company Size', 'Job Category', 'Primary Skill Category'],
#       dtype='object')

# %%
temp_df = df.copy()

# %%
temp_df = temp_df[temp_df['job_pay'] != 'Not disclosed']

# %%
temp_df['starting_range'] = temp_df['job_pay'].str.split('-',expand=True)[0]
temp_df['ending_range'] = temp_df['job_pay'].str.split('-',expand=True)[1]
temp_df['starting_range'].value_counts()
# Out:
# 3          196
# 2          144
# 2.5        112
# 1           94
# 4           79
# 2.25        51
# 5           49
# 1.75        47
# 1.5         46
# 50,000      38
# 1.25        35
# 3.5         32
# 2.75        30
# 6           28
# 10          26
# 3.25        17
# 7           17
# 8           16
# 4.5         15
# 3.75        11
# 15           9
# 5.5          8
# 6.5          7
# 9            7
# 4.25         6
# 4.75         5
# 20           4
# 7.5          3
# 14           3
# 90,000       3
# 12           3
# No data      3
# 70,000       3
# 25           2
# 80,000       2
# 11           2
# 60,000       2
# 90 Lacs      1
# 35           1
# 9.5          1
# 17           1
# 80 Lacs      1
# Name: starting_range, dtype: int64

# %%
temp_df['starting_range'] = temp_df['job_pay'].str.split('-',expand=True)[0]
temp_df['ending_range'] = temp_df['job_pay'].str.split('-',expand=True)[1]
temp_df['ending_range'] = temp_df['ending_range'].fillna('No data')

# Create a new column 'bonus' with default value 0
temp_df['bonus'] = 0

# Find rows where 'ending_range' contains '(' and set 'bonus' to 1 for those rows
temp_df.loc[temp_df['ending_range'].str.contains(r'\('), 'bonus'] = 1

indexes = temp_df[temp_df['ending_range'].str.contains(r'\(')].index

# Split 'ending_range' at '(' and take the first part
split_values = temp_df.loc[indexes, 'ending_range'].str.split(r'\(', expand=True)[0]

# Update the DataFrame with the split values
temp_df.loc[indexes, 'ending_range'] = split_values

# temp_df['ending_range'].str.replace(r'.*\(([^:]+): ([^\)]+)\).*', r'\0', regex=True)

# %%
# For rows where 'starting_range' is 'No data' and 'Company Size' is 'Very Large', set 'starting_range' to 7
temp_df.loc[(temp_df['ending_range'] == 'No data') & (temp_df['Company Size'] == 'Very Large'), 'ending_range'] = 1200000
temp_df.loc[(temp_df['ending_range'] == 'No data') & (temp_df['Company Size'] == 'Large'), 'ending_range'] = 1000000
temp_df.loc[(temp_df['ending_range'] == 'No data') & (temp_df['Company Size'] == 'Small'), 'ending_range'] = 500000
temp_df.loc[(temp_df['ending_range'] == 'No data') & (temp_df['Company Size'] == 'Very Small'), 'ending_range'] = 300000
temp_df.loc[(temp_df['job_pay'] == 'No data') & (temp_df['Company Size'] == 'Very Large'), 'starting_range'] = 900000
temp_df.loc[(temp_df['job_pay'] == 'No data') & (temp_df['Company Size'] == 'Large'), 'starting_range'] = 700000
temp_df.loc[(temp_df['job_pay'] == 'No data') & (temp_df['Company Size'] == 'Small'), 'starting_range'] = 500000
temp_df.loc[(temp_df['job_pay'] == 'No data') & (temp_df['Company Size'] == 'Very Small'), 'starting_range'] = 200000

# For rows where 'starting_range' is 'No data' and 'Company Size' is 'Large', set 'starting_range' to 5
temp_df.loc[(temp_df['ending_range'] == 'No data') & (temp_df['Company Size'] == 'Medium'), 'ending_range'] = 700000
temp_df.loc[(temp_df['job_pay'] == 'No data') & (temp_df['Company Size'] == 'Medium'), 'starting_range'] = 500000

# For rows where 'starting_range' is 'No data' and 'Company Size' is 'Small', set 'starting_range' to 3

# %%
temp_df
# Out:
#                                                 Job_role  \
# 16                                          Data Analyst
# 17                                          Data Analyst
# 18                                          Data Analyst
# 21                                          Data Analyst
# 24                                          Data Analyst
# ...                                                  ...
# 10123                                      Web Developer
# 10126               Sr. Web Developers ( php , laravel )
# 10149                            Fintech- Content Writer
# 10160  Customer Relationship Executive international BPO
# 10161      Email Support Associate For international BPO
#
#                                           Company  \
# 16                           Outscal Technologies
# 17                                         Redbus
# 18                                     Amiha Agro
# 21                   A K Infra Reality Developers
# 24                               Bolla Management
# ...                                           ...
# 10123                      Broomling Technologies
# 10126                        Vibhuti Technologies
# 10149                             Shriram finance
# 10160                     Leading MNC BPO Company
# 10161  Leading MNC BPO Company in Mohali location
#
#                                     job_pay  \
# 16                                    10-20
# 17                                      4-7
# 18                                  2.5-4.5
# 21                                   1.75-3
# 24     4.75-6.5 (Including Variable: 10.0%)
# ...                                     ...
# 10123                                 3-3.5
# 10126                                   3-5
# 10149                                   4-8
# 10160                                2.75-4
# 10161                                 2.5-4
#
#                                                 location  \
# 16                                                Remote
# 17                                       Bangalore Rural
# 18                         Ahmedabad(Shyamal Cross Road)
# 21                                               Lucknow
# 24                                   Hyderabad(Kondapur)
# ...                                                  ...
# 10123                                             Remote
# 10126                                             Mohali
# 10149                                          Bengaluru
# 10160  Mohali, Punjab, Chandigarh, Chandigarh, Kharar...
# 10161  Mohali, Punjab, Chandigarh, Chandigarh, Kharar...
#
#                                              Description  review  \
# 16     Bachelors degree in Data Science, Computer Sci...     4.3
# 17     Educational Qualifications - Graduate and abov...     4.3
# 18              Bachelors degree must 2 years experience     2.2
# 21     Developing and maintaining database and data s...     3.1
# 24     Job description: Qualifications: and Character...     5.0
# ...                                                  ...     ...
# 10123  Experience: Minimum 2 years. Troubleshoot and ...     4.2
# 10126  Proven experience as a PHP Developer, preferab...     4.2
# 10149  The people skills required to work with design...     4.0
# 10160  full salary for training period as well. 81465...     4.0
# 10161  call now Ms.Chadni 6230972380 candidates must ...     4.0
#
#        Job post length  min_year  max_year  more_branch  ...  norm_review  \
# 16                  12         0         3            1  ...        0.825
# 17                  12         1         3            2  ...        0.825
# 18                  12         2         4            3  ...        0.300
# 21                  12         2         4            1  ...        0.525
# 24                  12         2         6            1  ...        1.000
# ...                ...       ...       ...          ...  ...          ...
# 10123               13         2         3            1  ...        0.800
# 10126               36         2         6            1  ...        0.800
# 10149               23         2         7            1  ...        0.750
# 10160               49         0         5            6  ...        0.750
# 10161               45         0         5            6  ...        0.750
#
#        norm_branches norm_max_year composite_score Company Size  \
# 16                 0      0.100000        0.925000       Medium
# 17                 0      0.100000        0.925000       Medium
# 18                 1      0.133333        1.433333   Very Large
# 21                 0      0.133333        0.658333   Very Small
# 24                 0      0.200000        1.200000   Very Large
# ...              ...           ...             ...          ...
# 10123              0      0.100000        0.900000       Medium
# 10126              0      0.200000        1.000000        Large
# 10149              0      0.233333        0.983333        Large
# 10160              1      0.166667        1.916667   Very Large
# 10161              1      0.166667        1.916667   Very Large
#
#                     Job Category      Primary Skill Category starting_range  \
# 16             Data and Analysis               Data Analysis             10
# 17             Data and Analysis               Data Analysis              4
# 18             Data and Analysis               Data Analysis            2.5
# 21             Data and Analysis               Data Analysis           1.75
# 24             Data and Analysis  Business Intelligence (BI)           4.75
# ...                          ...                         ...            ...
# 10123  Developer and Engineering                        HTML              3
# 10126  Developer and Engineering                      Others              3
# 10149                     Others                      Others              4
# 10160           Customer Support                      Others           2.75
# 10161           Customer Support               International            2.5
#
#       ending_range bonus
# 16              20     0
# 17               7     0
# 18             4.5     0
# 21               3     0
# 24            6.5      1
# ...            ...   ...
# 10123          3.5     0
# 10126            5     0
# 10149            8     0
# 10160            4     0
# 10161            4     0
#
# [1160 rows x 33 columns]

# %%
def process_value(value):
    if isinstance(value, str):
        if 'Cr' in value:
            return float(value.replace(' Cr', '')) * 10000000
        elif ',' in value:
            return float(value.replace(',', '')) 
        else:
            return float(value) * 100000
    else:
        return value

# Applying the function to the column
temp_df['ending_range'] = temp_df['ending_range'].apply(process_value)
# def process_value(value):
#     if isinstance(value, str):
#         if 'Cr' in value:
#             return float(value.replace(' Cr', '')) * 10000000
#         elif ',' in value:
#             return float(value.replace(',', '')) 
#         else:
#             return float(value) * 100000
#     else:
#         return value
    



# # Applying the function to the column
temp_df['starting_range'] = temp_df['starting_range'].str.replace(' Lacs', '')
temp_df['starting_range'] = temp_df['starting_range'].apply(process_value)

# %%
# temp_df_df

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1160 entries, 16 to 10161
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Job_role                1160 non-null   object
#  1   Company                 1160 non-null   object
#  2   job_pay                 1160 non-null   object
#  3   location                1160 non-null   object
#  4   Description             1160 non-null   object
#  5   review                  1160 non-null   float64
#  6   Job post length         1160 non-null   int64
#  7   min_year                1160 non-null   int64
#  8   max_year                1160 non-null   int64
#  9   more_branch             1160 non-null   int64
#  10  +3_branches             1160 non-null   int64
#  11  days                    1160 non-null   int64
#  12  skill_1                 1160 non-null   object
#  13  skill_2                 1158 non-null   object
#  14  skill_3                 1154 non-null   object
#  15  skill_4                 1146 non-null   object
#  16  skill_5                 1136 non-null   object
#  17  skill_6                 1119 non-null   object
#  18  skill_7                 1102 non-null   object
#  19  skill_8                 1064 non-null   object
#  20  skill_9                 38 non-null     object
#  21  skill_10                8 non-null      object
#  22  is_remote               1160 non-null   int64
#  23  norm_review             1160 non-null   float64
#  24  norm_branches           1160 non-null   int64
#  25  norm_max_year           1160 non-null   float64
#  26  composite_score         1160 non-null   float64
#  27  Company Size            1160 non-null   object
#  28  Job Category            1160 non-null   object
#  29  Primary Skill Category  1160 non-null   object
#  30  starting_range          1157 non-null   float64
#  31  ending_range            1160 non-null   float64
#  32  bonus                   1160 non-null   int64
# dtypes: float64(6), int64(9), object(18)
# memory usage: 340.4+ KB

# %%
# temp_df['starting_range'].astype(int)
# temp_df['ending_range'].astype(int)
temp_df.drop(columns=['Description'],inplace=True)

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1160 entries, 16 to 10161
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Job_role                1160 non-null   object
#  1   Company                 1160 non-null   object
#  2   job_pay                 1160 non-null   object
#  3   location                1160 non-null   object
#  4   review                  1160 non-null   float64
#  5   Job post length         1160 non-null   int64
#  6   min_year                1160 non-null   int64
#  7   max_year                1160 non-null   int64
#  8   more_branch             1160 non-null   int64
#  9   +3_branches             1160 non-null   int64
#  10  days                    1160 non-null   int64
#  11  skill_1                 1160 non-null   object
#  12  skill_2                 1158 non-null   object
#  13  skill_3                 1154 non-null   object
#  14  skill_4                 1146 non-null   object
#  15  skill_5                 1136 non-null   object
#  16  skill_6                 1119 non-null   object
#  17  skill_7                 1102 non-null   object
#  18  skill_8                 1064 non-null   object
#  19  skill_9                 38 non-null     object
#  20  skill_10                8 non-null      object
#  21  is_remote               1160 non-null   int64
#  22  norm_review             1160 non-null   float64
#  23  norm_branches           1160 non-null   int64
#  24  norm_max_year           1160 non-null   float64
#  25  composite_score         1160 non-null   float64
#  26  Company Size            1160 non-null   object
#  27  Job Category            1160 non-null   object
#  28  Primary Skill Category  1160 non-null   object
#  29  starting_range          1157 non-null   float64
#  30  ending_range            1160 non-null   float64
#  31  bonus                   1160 non-null   int64
# dtypes: float64(6), int64(9), object(17)
# memory usage: 331.4+ KB

# %%
# temp_df.drop(temp_df['skill_7'].isnull().index,inplace=True)     
temp_df['normalized_salary'] = (temp_df['starting_range'] + temp_df['ending_range']) / 2

# %%
# temp_df.drop(columns=['skill_10'], inplace=True)
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1160 entries, 16 to 10161
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Job_role                1160 non-null   object
#  1   Company                 1160 non-null   object
#  2   job_pay                 1160 non-null   object
#  3   location                1160 non-null   object
#  4   review                  1160 non-null   float64
#  5   Job post length         1160 non-null   int64
#  6   min_year                1160 non-null   int64
#  7   max_year                1160 non-null   int64
#  8   more_branch             1160 non-null   int64
#  9   +3_branches             1160 non-null   int64
#  10  days                    1160 non-null   int64
#  11  skill_1                 1160 non-null   object
#  12  skill_2                 1158 non-null   object
#  13  skill_3                 1154 non-null   object
#  14  skill_4                 1146 non-null   object
#  15  skill_5                 1136 non-null   object
#  16  skill_6                 1119 non-null   object
#  17  skill_7                 1102 non-null   object
#  18  skill_8                 1064 non-null   object
#  19  skill_9                 38 non-null     object
#  20  skill_10                8 non-null      object
#  21  is_remote               1160 non-null   int64
#  22  norm_review             1160 non-null   float64
#  23  norm_branches           1160 non-null   int64
#  24  norm_max_year           1160 non-null   float64
#  25  composite_score         1160 non-null   float64
#  26  Company Size            1160 non-null   object
#  27  Job Category            1160 non-null   object
#  28  Primary Skill Category  1160 non-null   object
#  29  starting_range          1157 non-null   float64
#  30  ending_range            1160 non-null   float64
#  31  bonus                   1160 non-null   int64
#  32  normalized_salary       1157 non-null   float64
# dtypes: float64(7), int64(9), object(17)
# memory usage: 340.4+ KB

# %%
pd.read_excel('with_price.xlsx').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1160 non-null   int64
#  1   Job_role                1160 non-null   object
#  2   Company                 1160 non-null   object
#  3   job_pay                 1160 non-null   object
#  4   location                1160 non-null   object
#  5   review                  1160 non-null   float64
#  6   Job post length         1160 non-null   int64
#  7   min_year                1160 non-null   int64
#  8   max_year                1160 non-null   int64
#  9   more_branch             1160 non-null   int64
#  10  +3_branches             1160 non-null   int64
#  11  days                    1160 non-null   int64
#  12  skill_1                 1160 non-null   object
#  13  skill_2                 1158 non-null   object
#  14  skill_3                 1154 non-null   object
#  15  skill_4                 1146 non-null   object
#  16  skill_5                 1136 non-null   object
#  17  skill_6                 1119 non-null   object
#  18  skill_7                 1102 non-null   object
#  19  skill_8                 1064 non-null   object
#  20  skill_9                 38 non-null     object
#  21  skill_10                8 non-null      object
#  22  is_remote               1160 non-null   int64
#  23  norm_review             1160 non-null   float64
#  24  norm_branches           1160 non-null   int64
#  25  norm_max_year           1160 non-null   float64
#  26  composite_score         1160 non-null   float64
#  27  Company Size            1160 non-null   object
#  28  Job Category            1160 non-null   object
#  29  Primary Skill Category  1160 non-null   object
#  30  starting_range          1157 non-null   float64
#  31  ending_range            1160 non-null   int64
#  32  bonus                   1160 non-null   int64
#  33  normalized_salary       1157 non-null   float64
# dtypes: float64(6), int64(11), object(17)
# memory usage: 308.3+ KB

# %%
temp_df[temp_df['starting_range'].isna()]
# Out:
#                                                Job_role      Company  job_pay  \
# 3152  Snowflake/Databricks engineer, US relocation T...  Chatthechat  No data
# 4360                Data Analyst(0 Experience Required)     Peroptyx  No data
# 5677               Advanced Python Software Developer 2         Stim  No data
#
#                                             location  review  Job post length  \
# 3152  Hybrid - Chenani, Gurugram, Mumbai (All Areas)     3.1               70
# 4360                                          Remote     3.4               35
# 5677                                          Muscat     5.0               36
#
#       min_year  max_year  more_branch  +3_branches  ...  norm_branches  \
# 3152         1         6            9            1  ...              1
# 4360         0         5            1            0  ...              0
# 5677         0         4            1            0  ...              0
#
#      norm_max_year composite_score Company Size               Job Category  \
# 3152      0.200000        1.725000   Very Large          Data and Analysis
# 4360      0.166667        0.766667        Small          Data and Analysis
# 5677      0.133333        1.133333        Large  Developer and Engineering
#
#      Primary Skill Category starting_range ending_range bonus  \
# 3152                 Others            NaN    1200000.0     0
# 4360          Data Analysis            NaN     500000.0     0
# 5677          Data Analysis            NaN    1000000.0     0
#
#      normalized_salary
# 3152               NaN
# 4360               NaN
# 5677               NaN
#
# [3 rows x 33 columns]

# %%
temp_df.to_excel('with_price.xlsx')

# %%
temp_df_protect =  temp_df.copy()

# %%
df = temp_df.copy() 
# Create a list of unique skills
# Example: Define skill sets for job categories
unique_skills = set()
for i in range(1, 9):
    skill_col = f'skill_{i}'
    unique_skills.update(df[skill_col].dropna().unique())

# Create binary columns for each unique skill
for skill in unique_skills:
    df[skill] = 0

# Populate the binary columns
for i in range(1, 9):
    skill_col = f'skill_{i}'
    for skill in unique_skills:
        df[skill] = df[skill] | (df[skill_col] == skill).astype(int)

# Step 2: Skill Count
# Count non-null skill entries per row
df['total_skills'] = df[[f'skill_{i}' for i in range(1, 9)]].notnull().sum(axis=1)

# Step 3: Binary Encoding for Job Categories
# Get unique job categories
unique_job_categories = df['Job Category'].unique()

# Create binary columns for each job category
for category in unique_job_categories:
    df[category] = df['Job Category'] == category

# Convert boolean columns to integers (0 or 1)
df[unique_job_categories] = df[unique_job_categories].astype(int)

# Drop the original skill columns and 'Job Category' column if no longer needed
df.drop(columns=[f'skill_{i}' for i in range(1, 9)] + ['Job Category'], inplace=True)

df.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# ...
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2719597354.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[skill] = 0
#         Job_role  Company                               job_pay  \
# 16  Data Analyst        0                                 10-20
# 17  Data Analyst        0                                   4-7
# 18  Data Analyst        0                               2.5-4.5
# 21  Data Analyst        0                                1.75-3
# 24  Data Analyst        0  4.75-6.5 (Including Variable: 10.0%)
#
#                          location  review  Job post length  min_year  \
# 16                         Remote     4.3               12         0
# 17                Bangalore Rural     4.3               12         1
# 18  Ahmedabad(Shyamal Cross Road)     2.2               12         2
# 21                        Lucknow     3.1               12         2
# 24            Hyderabad(Kondapur)     5.0               12         2
#
#     max_year  more_branch  +3_branches  ...  HR Executive  \
# 16         3            1            0  ...             0
# 17         3            2            0  ...             0
# 18         4            3            1  ...             0
# 21         4            1            0  ...             0
# 24         6            1            0  ...             0
#
#    Enterprise Content Management Debt Collection  total_skills  \
# 16                             0               0             8
# 17                             0               0             8
# 18                             0               0             8
# 21                             0               0             8
# 24                             0               0             8
#
#     Data and Analysis  Management and Strategic Roles  Others  \
# 16                  1                               0       0
# 17                  1                               0       0
# 18                  1                               0       0
# 21                  1                               0       0
# 24                  1                               0       0
#
#     Marketing and Sales Developer and Engineering Creative and Design
# 16                    0                         0                   0
# 17                    0                         0                   0
# 18                    0                         0                   0
# 21                    0                         0                   0
# 24                    0                         0                   0
#
# [5 rows x 2913 columns]

# %%
df.columns

temp = pd.DataFrame(index = df.columns)
# df.drop(columns=['Company'],inplace=True)
temp['data_type'] = df.dtypes
temp['unique_value'] = df.nunique()
temp['corr_values'] = df.corr()['normalized_salary']
temp
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_36288\2293156677.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   temp['corr_values'] = df.corr()['normalized_salary']
#                                data_type  unique_value  corr_values
# Job_role                          object           882          NaN
# Company                            int64             2     0.008497
# job_pay                           object           278          NaN
# location                          object           490          NaN
# review                           float64            39     0.014214
# ...                                  ...           ...          ...
# Management and Strategic Roles     int32             2     0.012728
# Others                             int32             2    -0.089955
# Marketing and Sales                int32             2    -0.033693
# Developer and Engineering          int32             2     0.115414
# Creative and Design                int32             2    -0.017617
#
# [2913 rows x 3 columns]

# %%
df[]
# Out:
#   Cell In[22], line 1
#     df[]
#        ^
# SyntaxError: invalid syntax

# %%
df['Data and Analysis'].value_counts()

# %%
df['Job Category']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming the DataFrame `df` is already prepared as shown in your message

# Correlation Analysis
correlation_matrix = df.corr()

# Select salary-related columns to analyze
salary_corr_starting = correlation_matrix['starting_range'].sort_values(ascending=False)
salary_corr_ending = correlation_matrix['ending_range'].sort_values(ascending=False)

# Display top correlations with starting salary
print("Top correlations with starting salary:")
print(salary_corr_starting.head(10))

# Display top correlations with ending salary
print("Top correlations with ending salary:")
print(salary_corr_ending.head(10))

# Visualization of the correlation matrix for the top features
top_features_starting = salary_corr_starting.index[:10]
top_features_ending = salary_corr_ending.index[:10]

# Combine the unique top features for a comprehensive correlation matrix
top_features = list(set(top_features_starting).union(set(top_features_ending)))

# Heatmap for top features correlation
plt.figure(figsize=(12, 10))
sns.heatmap(df[top_features].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Top Features')
plt.show()

# Visualization: Boxplot of starting salary by total number of skills
plt.figure(figsize=(14, 7))
sns.boxplot(x='total_skills', y='starting_range', data=df)
plt.xticks(rotation=90)
plt.title('Starting Salary Range by Total Number of Skills')
plt.show()

# Visualization: Boxplot of ending salary by job categories
plt.figure(figsize=(14, 7))
sns.boxplot(x='Data and Analysis', y='ending_range', data=df)
plt.xticks(rotation=90)
plt.title('Ending Salary Range by Job Category: Data and Analysis')
plt.show()

# %%
# temp_df = temp_df[~temp_df['skill_3'].isna()]

# %%
temp_df

# %%
# # Assume we have a dictionary of skill importance
# skill_importance = {'Python': 5, 'Java': 4, 'SQL': 3, 'Machine Learning': 5, 'Deep Learning': 5,}

# # Create a new column for skill score 
# df['skill_score'] = 0

# # Calculate the skill score for each job
# for i in range(1, 11):
#     skill_col = f'skill_{i}'
#     df['skill_score'] += df[skill_col].map(skill_importance).fillna(0)

# print(df[['Job_role', 'skill_score']].head())

# %%
temp = pd.DataFrame()

temp['unique_skill'] = df.nunique()
temp['null_value'] = df.isnull().sum()
temp['null_value'] = df.isnull().sum()
temp

# %%
# import matplotlib
